# %% [markdown]
# ### Average Speed ​​Estimation in Traffic by Deep Learning Method Using IBB Traffic Data

# %% [markdown]
# #### Loading and importing required libraries

# %%
# !pip install pandas
# !pip install numpy
# !pip install keras
# !pip install tensorflow
# !pip install matplotlib
# !pip install scikit-learn

# %%
# !pip install numpy

# %%
# !pip install keras

# %%
# !pip install tensorflow

# %%
# !pip install matplotlib

# %%
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense

# %% [markdown]
# ### We are reading train data(2020 12 months data). #Data was taken as csv from the Ibb website.

# %%
df = pd.read_csv(r'C:\Users\berrin.gocer\df_new.csv')

# %%
df.head()
# Out:
#       _id            DATE_TIME   LATITUDE  LONGITUDE GEOHASH  MINIMUM_SPEED  \
# 0  1890.0  2020-01-01T00:00:00  29.207153  40.976257  sxkc0e            113
# 1  3147.0  2020-01-01T01:00:00  29.207153  40.976257  sxkc0e            119
# 2  6099.0  2020-01-01T02:00:00  29.207153  40.976257  sxkc0e            131
# 3  8686.0  2020-01-01T03:00:00  29.207153  40.976257  sxkc0e            123
# 4  9476.0  2020-01-01T04:00:00  29.207153  40.976257  sxkc0e            114
#
#    MAXIMUM_SPEED  AVERAGE_SPEED  NUMBER_OF_VEHICLES
# 0             19             77                  40
# 1             13             72                  43
# 2             19             70                  33
# 3             34             81                  16
# 4             28             65                  13

# %%
#kordinatlardan konumun bulunması
from geopy.geocoders import Nominatim

# Koordinatları adreslere dönüştürme
geolocator = Nominatim(user_agent="adres_bulma")
location = geolocator.reverse("40.976257, 29.207153", language='tr')

# Adresi kontrol etme
print(location.address)
# Out:
# Samandıra, Samandıra Caddesi, Eyüp Sultan Mahallesi, Sancaktepe, İstanbul, Marmara Bölgesi, 34885, Türkiye

# %% [markdown]
# #### Coordinate Address Used: Samandıra, Samandıra Caddesi, Eyüp Sultan District, Sancaktepe, Istanbul, Marmara Region, 34885, Turkey

# %%
#deletion of columns that are not used in the model
df = df.drop(['_id', 'GEOHASH','LATITUDE','LONGITUDE'], axis=1)

# %%
df
# Out:
#                 DATE_TIME  MINIMUM_SPEED  MAXIMUM_SPEED  AVERAGE_SPEED  \
# 0     2020-01-01T00:00:00            113             19             77
# 1     2020-01-01T01:00:00            119             13             72
# 2     2020-01-01T02:00:00            131             19             70
# 3     2020-01-01T03:00:00            123             34             81
# 4     2020-01-01T04:00:00            114             28             65
# ...                   ...            ...            ...            ...
# 8637  2020-12-31 19:00:00            112              6             54
# 8638  2020-12-31 20:00:00            124              6             60
# 8639  2020-12-31 21:00:00            114              8             49
# 8640  2020-12-31 22:00:00            114              7             61
# 8641  2020-12-31 23:00:00            108             13             61
#
#       NUMBER_OF_VEHICLES
# 0                     40
# 1                     43
# 2                     33
# 3                     16
# 4                     13
# ...                  ...
# 8637                 140
# 8638                  95
# 8639                  42
# 8640                  23
# 8641                  39
#
# [8642 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8642 entries, 0 to 8641
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DATE_TIME           8642 non-null   object
#  1   MINIMUM_SPEED       8642 non-null   int64
#  2   MAXIMUM_SPEED       8642 non-null   int64
#  3   AVERAGE_SPEED       8642 non-null   int64
#  4   NUMBER_OF_VEHICLES  8642 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 337.7+ KB

# %% [markdown]
# ## Compression is performed to make time data more meaningful

# %%
# We convert the column we received as DATE_TIME object to date format
df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])

#Data compression takes place here
df['DATE_TIME'] = df['DATE_TIME'].dt.floor('4H')
df = df.groupby('DATE_TIME').agg({'AVERAGE_SPEED': 'mean', 'MINIMUM_SPEED': 'mean', 'MAXIMUM_SPEED': 'mean', 'NUMBER_OF_VEHICLES': 'mean'}).reset_index()


# Convert 'DATE_TIME' column to timestamp
df['TIMESTAMP'] = df['DATE_TIME'].values.astype(np.int64) // 10**9

# %%
df.head()
# Out:
#             DATE_TIME  AVERAGE_SPEED  MINIMUM_SPEED  MAXIMUM_SPEED  \
# 0 2020-01-01 00:00:00          75.00         121.50          21.25
# 1 2020-01-01 04:00:00          64.25         113.00          19.75
# 2 2020-01-01 08:00:00          57.00         113.00           8.50
# 3 2020-01-01 12:00:00          60.50         124.75           6.50
# 4 2020-01-01 16:00:00          60.00         118.00           7.50
#
#    NUMBER_OF_VEHICLES   TIMESTAMP
# 0               33.00  1577836800
# 1               19.50  1577851200
# 2               45.25  1577865600
# 3               89.25  1577880000
# 4               85.00  1577894400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2170 entries, 0 to 2169
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DATE_TIME           2170 non-null   datetime64[ns]
#  1   AVERAGE_SPEED       2170 non-null   float64
#  2   MINIMUM_SPEED       2170 non-null   float64
#  3   MAXIMUM_SPEED       2170 non-null   float64
#  4   NUMBER_OF_VEHICLES  2170 non-null   float64
#  5   TIMESTAMP           2170 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 101.8 KB

# %% [markdown]
# # Model Stage

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import TensorBoard
import numpy as np

# Select required columns
#X: Represents Feature
#Y: Represents Target
X = df[['TIMESTAMP', 'MINIMUM_SPEED', 'MAXIMUM_SPEED', 'NUMBER_OF_VEHICLES']].values
y = df['AVERAGE_SPEED'].values

# Split the dataset into training and testing
#Test and train data: model learns in train, how much the model learns in test data is tested comparatively
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
y_train = scaler.fit_transform(y_train.reshape(-1, 1))
y_test = scaler.transform(y_test.reshape(-1, 1))

# Creating an LSTM model
model = Sequential()
model.add(LSTM(128, input_shape=(1, X_train.shape[1])))  # Zaman adımı ekledik
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

# Define TensorBoard callback
tensorboard_callback = TensorBoard(log_dir='./logs', histogram_freq=1, write_graph=True, write_images=True)

# Train a model and use my TensorBoard callback
history = model.fit(np.expand_dims(X_train, axis=1), y_train, epochs=200, batch_size=64, callbacks=[tensorboard_callback], validation_data=(np.expand_dims(X_test, axis=1), y_test))
# Out:
# Epoch 1/200
# 28/28 [==============================] - 4s 42ms/step - loss: 0.0613 - val_loss: 0.0187
# Epoch 2/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0116 - val_loss: 0.0074
# Epoch 3/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 4/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0068 - val_loss: 0.0054
# Epoch 5/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0055
# Epoch 6/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0066 - val_loss: 0.0054
# Epoch 7/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0065 - val_loss: 0.0055
# Epoch 8/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 9/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0062 - val_loss: 0.0059
# Epoch 10/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0062 - val_loss: 0.0088
# Epoch 11/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 12/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 13/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 14/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0085
# Epoch 15/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 16/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 17/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 18/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0074
# Epoch 19/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0064
# Epoch 20/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0055 - val_loss: 0.0080
# Epoch 21/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0055 - val_loss: 0.0070
# Epoch 22/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0054 - val_loss: 0.0089
# Epoch 23/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 24/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 25/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 26/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 27/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 28/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0045
# Epoch 29/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0056 - val_loss: 0.0058
# Epoch 30/200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0055 - val_loss: 0.0046
# Epoch 31/200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 32/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0053 - val_loss: 0.0064
# Epoch 33/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0051 - val_loss: 0.0071
# Epoch 34/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0059
# Epoch 35/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 36/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 37/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0073
# Epoch 38/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0058
# Epoch 39/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0056
# Epoch 40/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 41/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 42/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0051 - val_loss: 0.0051
# Epoch 43/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0051 - val_loss: 0.0066
# Epoch 44/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0052 - val_loss: 0.0064
# Epoch 45/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0044
# Epoch 46/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0054 - val_loss: 0.0046
# Epoch 47/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0049 - val_loss: 0.0065
# Epoch 48/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0050 - val_loss: 0.0054
# Epoch 49/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0075
# Epoch 50/200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 51/200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 52/200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0049 - val_loss: 0.0058
# Epoch 53/200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0051 - val_loss: 0.0075
# Epoch 54/200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0052 - val_loss: 0.0045
# Epoch 55/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0045
# Epoch 56/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 57/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 58/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 59/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0063
# Epoch 60/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 61/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 62/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0049 - val_loss: 0.0047
# Epoch 63/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0076
# Epoch 64/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0064
# Epoch 65/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 66/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0051 - val_loss: 0.0049
# Epoch 67/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0069
# Epoch 68/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0052
# Epoch 69/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0057
# Epoch 70/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 71/200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0049 - val_loss: 0.0059
# Epoch 72/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0057
# Epoch 73/200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 74/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 75/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 76/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0050 - val_loss: 0.0057
# Epoch 77/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0061
# Epoch 78/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0048 - val_loss: 0.0061
# Epoch 79/200
# 28/28 [==============================] - 0s 12ms/step - loss: 0.0047 - val_loss: 0.0052
# Epoch 80/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 81/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 82/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0059
# Epoch 83/200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 84/200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.0047 - val_loss: 0.0055
# Epoch 85/200
# 28/28 [==============================] - 1s 22ms/step - loss: 0.0046 - val_loss: 0.0059
# Epoch 86/200
# 28/28 [==============================] - 1s 18ms/step - loss: 0.0046 - val_loss: 0.0079
# Epoch 87/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0051
# Epoch 88/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 89/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0066
# Epoch 90/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 91/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 92/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0049 - val_loss: 0.0057
# Epoch 93/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 94/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0055
# Epoch 95/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0078
# Epoch 96/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0077
# Epoch 97/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0060
# Epoch 98/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 99/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0061
# Epoch 100/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0054
# Epoch 101/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0049
# Epoch 102/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0055
# Epoch 103/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0059
# Epoch 104/200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0079
# Epoch 105/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0049 - val_loss: 0.0064
# Epoch 106/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0051
# Epoch 107/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0056
# Epoch 108/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0061
# Epoch 109/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 110/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0101
# Epoch 111/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 112/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0055
# Epoch 113/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 114/200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.0046 - val_loss: 0.0064
# Epoch 115/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 116/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 117/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0059
# Epoch 118/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0065
# Epoch 119/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 120/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 121/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0050 - val_loss: 0.0060
# Epoch 122/200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0046 - val_loss: 0.0061
# Epoch 123/200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0045 - val_loss: 0.0055
# Epoch 124/200
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 125/200
# 28/28 [==============================] - 1s 24ms/step - loss: 0.0046 - val_loss: 0.0065
# Epoch 126/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0056
# Epoch 127/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0111
# Epoch 128/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0060
# Epoch 129/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0061
# Epoch 130/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0070
# Epoch 131/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0059
# Epoch 132/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 133/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0071
# Epoch 134/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0045 - val_loss: 0.0061
# Epoch 135/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0059
# Epoch 136/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0045 - val_loss: 0.0071
# Epoch 137/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0046 - val_loss: 0.0082
# Epoch 138/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0045 - val_loss: 0.0069
# Epoch 139/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0063
# Epoch 140/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0062
# Epoch 141/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0077
# Epoch 142/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0077
# Epoch 143/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0064
# Epoch 144/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0049 - val_loss: 0.0072
# Epoch 145/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0047 - val_loss: 0.0067
# Epoch 146/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0061
# Epoch 147/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0064
# Epoch 148/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0046 - val_loss: 0.0055
# Epoch 149/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0061
# Epoch 150/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0066
# Epoch 151/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0070
# Epoch 152/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0087
# Epoch 153/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0046 - val_loss: 0.0074
# Epoch 154/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0066
# Epoch 155/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0067
# Epoch 156/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0065
# Epoch 157/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0067
# Epoch 158/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0048 - val_loss: 0.0072
# Epoch 159/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0103
# Epoch 160/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0048 - val_loss: 0.0074
# Epoch 161/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0076
# Epoch 162/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0045 - val_loss: 0.0074
# Epoch 163/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0058
# Epoch 164/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0087
# Epoch 165/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0060
# Epoch 166/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0045 - val_loss: 0.0063
# Epoch 167/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0069
# Epoch 168/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0070
# Epoch 169/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0046 - val_loss: 0.0058
# Epoch 170/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0044 - val_loss: 0.0079
# Epoch 171/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0070
# Epoch 172/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0058
# Epoch 173/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0089
# Epoch 174/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0047 - val_loss: 0.0079
# Epoch 175/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 176/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0068
# Epoch 177/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0067
# Epoch 178/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0086
# Epoch 179/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0072
# Epoch 180/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0044 - val_loss: 0.0081
# Epoch 181/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0043 - val_loss: 0.0061
# Epoch 182/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0043 - val_loss: 0.0069
# Epoch 183/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0042 - val_loss: 0.0060
# Epoch 184/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0074
# Epoch 185/200
# 28/28 [==============================] - 0s 18ms/step - loss: 0.0043 - val_loss: 0.0063
# Epoch 186/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0043 - val_loss: 0.0055
# Epoch 187/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0044 - val_loss: 0.0064
# Epoch 188/200
# 28/28 [==============================] - 0s 17ms/step - loss: 0.0043 - val_loss: 0.0083
# Epoch 189/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0044 - val_loss: 0.0064
# Epoch 190/200
# 28/28 [==============================] - 0s 15ms/step - loss: 0.0042 - val_loss: 0.0065
# Epoch 191/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0042 - val_loss: 0.0062
# Epoch 192/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0070
# Epoch 193/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0089
# Epoch 194/200
# 28/28 [==============================] - 0s 14ms/step - loss: 0.0042 - val_loss: 0.0096
# Epoch 195/200
# 28/28 [==============================] - 0s 16ms/step - loss: 0.0043 - val_loss: 0.0072
# Epoch 196/200
# 28/28 [==============================] - 0s 13ms/step - loss: 0.0043 - val_loss: 0.0076
# Epoch 197/200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0043 - val_loss: 0.0083
# Epoch 198/200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0043 - val_loss: 0.0071
# Epoch 199/200
# 28/28 [==============================] - 1s 21ms/step - loss: 0.0043 - val_loss: 0.0060
# Epoch 200/200
# 28/28 [==============================] - 1s 20ms/step - loss: 0.0043 - val_loss: 0.0069

# %%
# Make predictions on test data
y_pred = model.predict(np.expand_dims(X_test, axis=1))

# Reverse normalization of prediction results
y_pred = scaler.inverse_transform(y_pred)

# Comparing actual and predicted values
comparison = pd.DataFrame({'Gerçek': scaler.inverse_transform(y_test.reshape(-1, 1)).flatten(), 'Tahmin': y_pred.flatten()})
print(comparison)
# Out:
# 14/14 [==============================] - 0s 5ms/step
#        Gerçek    Tahmin
# 0    3.603550  3.701647
# 1    3.544379  3.511878
# 2    3.236686  3.254010
# 3    3.366864  3.275204
# 4    3.337278  3.300874
# ..        ...       ...
# 429  3.544379  3.504015
# 430  3.307692  3.216861
# 431  3.437870  3.297698
# 432  3.449704  3.230125
# 433  3.591716  3.629245
#
# [434 rows x 2 columns]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               68096
#
#  dense (Dense)               (None, 256)               33024
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 167,169
# Trainable params: 167,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

# Comparing actual and predicted values
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Graph creation
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')

plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.legend()
plt.show()

# %% [markdown]
# ### Model Performance on Train and Test data # R-Square #MSE #MAE Calculations
# ### R-Square ranges from 0 to 1 and represents an increase in model performance as it approaches 1.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

train_preds = model.predict(np.expand_dims(X_train, axis=1))
train_r2 = r2_score(y_train, train_preds)
print("Train R2 Skoru: {:.4f}".format(train_r2))

test_preds = model.predict(np.expand_dims(X_test, axis=1))
test_r2 = r2_score(y_test, test_preds)
print("Test R2 Skoru: {:.4f}".format(test_r2))
# Out:
# 55/55 [==============================] - 0s 4ms/step
# Train R2 Skoru: 0.7763
# 14/14 [==============================] - 0s 5ms/step
# Test R2 Skoru: 0.6426

# %% [markdown]
# ### MSE - Mean Squared Error (error rate) The closer to 0, the better the model yield

# %%
train_preds = model.predict(np.expand_dims(X_train, axis=1))
train_mse = mean_squared_error(y_train, train_preds)
train_mae = mean_absolute_error(y_train, train_preds)
print("Train MSE: {:.4f}".format(train_mse))
# Out:
# 55/55 [==============================] - 0s 3ms/step
# Train MSE: 0.0040

# %% [markdown]
# ### MAE - Mean Absolute Error The closer to 0, the better the model yield

# %%
test_preds = model.predict(np.expand_dims(X_test, axis=1))
test_mse = mean_squared_error(y_test, test_preds)
test_mae = mean_absolute_error(y_test, test_preds)
print("Test MAE: {:.4f}".format(test_mae))
# Out:
# 14/14 [==============================] - 0s 2ms/step
# Test MAE: 0.0684

# %% [markdown]
# # Model Outputs: Predicted & Target

# %%
# Make predictions on test data
y_pred = model.predict(np.expand_dims(X_test, axis=1))

# Reverse normalization of prediction results
y_pred = scaler.inverse_transform(y_pred)

# Comparing actual and predicted values
comparison = pd.DataFrame({'Gerçek': scaler.inverse_transform(y_test.reshape(-1, 1)).flatten(), 'Tahmin': y_pred.flatten()})
print(comparison)
# Out:
# 14/14 [==============================] - 0s 2ms/step
#        Gerçek    Tahmin
# 0    3.603550  3.701647
# 1    3.544379  3.511878
# 2    3.236686  3.254010
# 3    3.366864  3.275204
# 4    3.337278  3.300874
# ..        ...       ...
# 429  3.544379  3.504015
# 430  3.307692  3.216861
# 431  3.437870  3.297698
# 432  3.449704  3.230125
# 433  3.591716  3.629245
#
# [434 rows x 2 columns]

# %% [markdown]
# # Querying the predict value for the desired date to the model

# %% [markdown]
# ##### First, the desired date is entered manually in the date_string section.
# ##### Since this data model is trained with timestamp data, it is converted to timestamp format and predict value is obtained.

# %%
# Specify the date and time value
date_string = '2020-01-01 10:00:00'

# Convert date and time value to datetime format
date_time = pd.to_datetime(date_string)

# Converting date and time value to timestamp format and printing
timestamp = date_time.timestamp()
print(timestamp)
# Out:
# 1577872800.0

# %%
df.head()
# Out:
#             DATE_TIME  AVERAGE_SPEED  MINIMUM_SPEED  MAXIMUM_SPEED  \
# 0 2020-01-01 00:00:00          75.00         121.50          21.25
# 1 2020-01-01 04:00:00          64.25         113.00          19.75
# 2 2020-01-01 08:00:00          57.00         113.00           8.50
# 3 2020-01-01 12:00:00          60.50         124.75           6.50
# 4 2020-01-01 16:00:00          60.00         118.00           7.50
#
#    NUMBER_OF_VEHICLES   TIMESTAMP
# 0               33.00  1577836800
# 1               19.50  1577851200
# 2               45.25  1577865600
# 3               89.25  1577880000
# 4               85.00  1577894400

# %%
# X: Features: ['TIMESTAMP', 'MINIMUM_SPEED', 'MAXIMUM_SPEED', 'NUMBER_OF_VEHICLES']
# Y: Target:  AVERAGE_SPEED

input_data = np.array([[timestamp, 50, 140, 3]])

# Create MinMaxScaler objects to normalize each feature individually
scalers = []
for _ in range(input_data.shape[1]):
    scaler = MinMaxScaler()
    scalers.append(scaler)

# Normalize each feature separately
input_data_scaled = np.empty_like(input_data)
for i, scaler in enumerate(scalers):
    input_data_scaled[:, i] = scaler.fit_transform(input_data[:, i].reshape(-1, 1)).flatten()

# %%
# Reshape and predict input data
input_data_reshaped = np.expand_dims(input_data_scaled, axis=1)
y_pred = model.predict(input_data_reshaped)

# Reverse normalize the prediction result
predicted_average_speed = scalers[-1].inverse_transform(y_pred)
# Out:
# 1/1 [==============================] - 0s 23ms/step
